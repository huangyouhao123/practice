# %%
import numpy as np
import matplotlib as plt
import pandas as pd
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x000001C8C0745640>

# %%
path="E:\pythonproject4\pachong\weather.xlsx"
data=pd.read_excel(path)
data
# Out:
#       Unnamed: 0             日期  最高温  最低温     天气     风力风向 空气质量指数
# 0              0  2018-01-01 周一   5°  -1°   多云~阴  西北风4-5级   61 良
# 1              1  2018-01-02 周二   3°  -3°   阴~多云   北风4-5级   60 良
# 2              2  2018-01-03 周三   0°  -3°     多云   北风5-6级   38 优
# 3              3  2018-01-04 周四  -1°  -3°   多云~阴   北风4-5级   34 优
# 4              4  2018-01-05 周五   1°  -2°     多云   北风4-5级   33 优
# ...          ...            ...  ...  ...    ...      ...    ...
# 2186          26  2023-12-27 周三   3°  -4°      晴     东风1级      -
# 2187          27  2023-12-28 周四   3°  -4°     多云    西北风3级      -
# 2188          28  2023-12-29 周五   4°   2°  多云~小雨    西南风2级      -
# 2189          29  2023-12-30 周六   7°   0°  雾~雨夹雪    西南风2级      -
# 2190          30  2023-12-31 周日   1°  -2°   阴~多云    西北风6级   61 良
#
# [2191 rows x 7 columns]

# %%
string="abcd"
string=string[1]
string
# Out:
# 'b'

# %%
data['最高温'] = data['最高温'].apply(lambda x: int(float(x[0:-1])) if len(x) > 0 else 0)
data['最低温'] = data['最低温'].apply(lambda x: int(float(x[0:-1])) if len(x) > 0 else 0)

# %%
data
# Out:
#       Unnamed: 0             日期  最高温  最低温     天气     风力风向 空气质量指数
# 0              0  2018-01-01 周一    5   -1   多云~阴  西北风4-5级   61 良
# 1              1  2018-01-02 周二    3   -3   阴~多云   北风4-5级   60 良
# 2              2  2018-01-03 周三    0   -3     多云   北风5-6级   38 优
# 3              3  2018-01-04 周四   -1   -3   多云~阴   北风4-5级   34 优
# 4              4  2018-01-05 周五    1   -2     多云   北风4-5级   33 优
# ...          ...            ...  ...  ...    ...      ...    ...
# 2186          26  2023-12-27 周三    3   -4      晴     东风1级      -
# 2187          27  2023-12-28 周四    3   -4     多云    西北风3级      -
# 2188          28  2023-12-29 周五    4    2  多云~小雨    西南风2级      -
# 2189          29  2023-12-30 周六    7    0  雾~雨夹雪    西南风2级      -
# 2190          30  2023-12-31 周日    1   -2   阴~多云    西北风6级   61 良
#
# [2191 rows x 7 columns]

# %%
length=len(data)
x=np.arange(length)
y1=np.array(data["最高温"])
y2=np.array(data["最低温"])
plt.plot(x,y1)
plt.
